# %% [markdown]
# # This notebook makes a 17g6a3 pPb vs 16c3b pp Monte-carlo comparison

# %%
import ROOT
from ROOT import TH1, TCanvas, TFile, TLatex, TLegend, TMath

# %%
# Load in files from 17g6a3
MCData_pthat1 = TFile("JetJet_config_17g6a3_pthat1.root", "READ")
MCData_pthat2 = TFile("JetJet_config_17g6a3_pthat2.root", "READ")
MCData_pthat3 = TFile("JetJet_config_17g6a3_pthat3.root", "READ")
MCData_pthat4 = TFile("JetJet_config_17g6a3_pthat4.root", "READ")

# Load in the file from 16c3b
ppMCData = TFile("JetJet_config_16c3b_pthat1to4.root", "READ")

# %%
#Collect the data from 17g6a3
Xj_MC_pthat1 = MCData_pthat1.Get("hjet_Xj")
Xjtruth_MC_pthat1 = MCData_pthat1.Get("hjet_Xj_truth")
Xj_MC_pthat2 = MCData_pthat2.Get("hjet_Xj")
Xjtruth_MC_pthat2 = MCData_pthat2.Get("hjet_Xj_truth")
Xj_MC_pthat3 = MCData_pthat3.Get("hjet_Xj")
Xjtruth_MC_pthat3 = MCData_pthat3.Get("hjet_Xj_truth")
Xj_MC_pthat4 = MCData_pthat4.Get("hjet_Xj")
Xjtruth_MC_pthat4 = MCData_pthat4.Get("hjet_Xj_truth")

dPhi_MC_pthat1 = MCData_pthat1.Get("hjet_dPhi")
dPhitruth_MC_pthat1 = MCData_pthat1.Get("hjet_dPhi_truth")
dPhi_MC_pthat2 = MCData_pthat2.Get("hjet_dPhi")
dPhitruth_MC_pthat2 = MCData_pthat2.Get("hjet_dPhi_truth")
dPhi_MC_pthat3 = MCData_pthat3.Get("hjet_dPhi")
dPhitruth_MC_pthat3 = MCData_pthat3.Get("hjet_dPhi_truth")
dPhi_MC_pthat4 = MCData_pthat4.Get("hjet_dPhi")
dPhitruth_MC_pthat4 = MCData_pthat4.Get("hjet_dPhi_truth")

ptD_MC_pthat1 = MCData_pthat1.Get("hjet_ptD")
ptD_MC_pthat2 = MCData_pthat2.Get("hjet_ptD")
ptD_MC_pthat3 = MCData_pthat3.Get("hjet_ptD")
ptD_MC_pthat4 = MCData_pthat4.Get("hjet_ptD")

Multiplicity_MC_pthat1 = MCData_pthat1.Get("hjet_Multiplicity")
Multiplicity_MC_pthat2 = MCData_pthat2.Get("hjet_Multiplicity")
Multiplicity_MC_pthat3 = MCData_pthat3.Get("hjet_Multiplicity")
Multiplicity_MC_pthat4 = MCData_pthat4.Get("hjet_Multiplicity")

dEta_MC_pthat1 = MCData_pthat1.Get("hjet_dEta")
dEtatruth_MC_pthat1 = MCData_pthat1.Get("hjet_dEta_truth")
dEta_MC_pthat2 = MCData_pthat2.Get("hjet_dEta")
dEtatruth_MC_pthat2 = MCData_pthat2.Get("hjet_dEta_truth")
dEta_MC_pthat3 = MCData_pthat3.Get("hjet_dEta")
dEtatruth_MC_pthat3 = MCData_pthat3.Get("hjet_dEta_truth")
dEta_MC_pthat4 = MCData_pthat4.Get("hjet_dEta")
dEtatruth_MC_pthat4 = MCData_pthat4.Get("hjet_dEta_truth")

AvgEta_MC_pthat1 = MCData_pthat1.Get("hjet_AvgEta")
AvgEtatruth_MC_pthat1 = MCData_pthat1.Get("hjet_AvgEta_truth")
AvgEta_MC_pthat2 = MCData_pthat2.Get("hjet_AvgEta")
AvgEtatruth_MC_pthat2 = MCData_pthat2.Get("hjet_AvgEta_truth")
AvgEta_MC_pthat3 = MCData_pthat3.Get("hjet_AvgEta")
AvgEtatruth_MC_pthat3 = MCData_pthat3.Get("hjet_AvgEta_truth")
AvgEta_MC_pthat4 = MCData_pthat4.Get("hjet_AvgEta")
AvgEtatruth_MC_pthat4 = MCData_pthat4.Get("hjet_AvgEta_truth")

leading_pT_MC_pthat1 = MCData_pthat1.Get("hjet_leading_pT")
leading_PTtruth_MC_pthat1 = MCData_pthat1.Get("hjet_leading_pT_truth")
leading_pT_MC_pthat2 = MCData_pthat2.Get("hjet_leading_pT")
leading_PTtruth_MC_pthat2 = MCData_pthat2.Get("hjet_leading_pT_truth")
leading_pT_MC_pthat3 = MCData_pthat3.Get("hjet_leading_pT")
leading_PTtruth_MC_pthat3 = MCData_pthat3.Get("hjet_leading_pT_truth")
leading_pT_MC_pthat4 = MCData_pthat4.Get("hjet_leading_pT")
leading_PTtruth_MC_pthat4 = MCData_pthat4.Get("hjet_leading_pT_truth")

leading_Eta_MC_pthat1 = MCData_pthat1.Get("hjet_leading_Eta")
leading_Etatruth_MC_pthat1 = MCData_pthat1.Get("hjet_leading_Eta_truth")
leading_Eta_MC_pthat2 = MCData_pthat2.Get("hjet_leading_Eta")
leading_Etatruth_MC_pthat2 = MCData_pthat2.Get("hjet_leading_Eta_truth")
leading_Eta_MC_pthat3 = MCData_pthat3.Get("hjet_leading_Eta")
leading_Etatruth_MC_pthat3 = MCData_pthat3.Get("hjet_leading_Eta_truth")
leading_Eta_MC_pthat4 = MCData_pthat4.Get("hjet_leading_Eta")
leading_Etatruth_MC_pthat4 = MCData_pthat4.Get("hjet_leading_Eta_truth")

leading_Phi_MC_pthat1 = MCData_pthat1.Get("hjet_leading_Phi")
leading_Phitruth_MC_pthat1 = MCData_pthat1.Get("hjet_leadingPhi_truth")
leading_Phi_MC_pthat2 = MCData_pthat2.Get("hjet_leading_Phi")
leading_Phitruth_MC_pthat2 = MCData_pthat2.Get("hjet_leadingPhi_truth")
leading_Phi_MC_pthat3 = MCData_pthat3.Get("hjet_leading_Phi")
leading_Phitruth_MC_pthat3 = MCData_pthat3.Get("hjet_leadingPhi_truth")
leading_Phi_MC_pthat4 = MCData_pthat4.Get("hjet_leading_Phi")
leading_Phitruth_MC_pthat4 = MCData_pthat4.Get("hjet_leadingPhi_truth")

# Collect the data from 16c3b
Xj_ppMC_pthat1 = ppMCData.Get("hjet_Xj")
Xjtruth_ppMC_pthat1 = ppMCData.Get("hjet_Xj_truth")
Xj_ppMC_pthat2 = ppMCData.Get("hjet_Xj")
Xjtruth_ppMC_pthat2 = ppMCData.Get("hjet_Xj_truth")
Xj_ppMC_pthat3 = ppMCData.Get("hjet_Xj")
Xjtruth_ppMC_pthat3 = ppMCData.Get("hjet_Xj_truth")
Xj_ppMC_pthat4 = ppMCData.Get("hjet_Xj")
Xjtruth_ppMC_pthat4 = ppMCData.Get("hjet_Xj_truth")

dPhi_ppMC_pthat1 = ppMCData.Get("hjet_dPhi")
dPhitruth_ppMC_pthat1 = ppMCData.Get("hjet_dPhi_truth")
dPhi_ppMC_pthat2 = ppMCData.Get("hjet_dPhi")
dPhitruth_ppMC_pthat2 = ppMCData.Get("hjet_dPhi_truth")
dPhi_ppMC_pthat3 = ppMCData.Get("hjet_dPhi")
dPhitruth_ppMC_pthat3 = ppMCData.Get("hjet_dPhi_truth")
dPhi_ppMC_pthat4 = ppMCData.Get("hjet_dPhi")
dPhitruth_ppMC_pthat4 = ppMCData.Get("hjet_dPhi_truth")

ptD_ppMC_pthat1 = ppMCData.Get("hjet_ptD")
ptD_ppMC_pthat2 = ppMCData.Get("hjet_ptD")
ptD_ppMC_pthat3 = ppMCData.Get("hjet_ptD")
ptD_ppMC_pthat4 = ppMCData.Get("hjet_ptD")

Multiplicity_ppMC_pthat1 = ppMCData.Get("hjet_Multiplicity")
Multiplicity_ppMC_pthat2 = ppMCData.Get("hjet_Multiplicity")
Multiplicity_ppMC_pthat3 = ppMCData.Get("hjet_Multiplicity")
Multiplicity_ppMC_pthat4 = ppMCData.Get("hjet_Multiplicity")

dEta_ppMC_pthat1 = ppMCData.Get("hjet_dEta")
dEtatruth_ppMC_pthat1 = ppMCData.Get("hjet_dEta_truth")
dEta_ppMC_pthat2 = ppMCData.Get("hjet_dEta")
dEtatruth_ppMC_pthat2 = ppMCData.Get("hjet_dEta_truth")
dEta_ppMC_pthat3 = ppMCData.Get("hjet_dEta")
dEtatruth_ppMC_pthat3 = ppMCData.Get("hjet_dEta_truth")
dEta_ppMC_pthat4 = ppMCData.Get("hjet_dEta")
dEtatruth_ppMC_pthat4 = ppMCData.Get("hjet_dEta_truth")

AvgEta_ppMC_pthat1 = ppMCData.Get("hjet_AvgEta")
AvgEtatruth_ppMC_pthat1 = ppMCData.Get("hjet_AvgEta_truth")
AvgEta_ppMC_pthat2 = ppMCData.Get("hjet_AvgEta")
AvgEtatruth_ppMC_pthat2 = ppMCData.Get("hjet_AvgEta_truth")
AvgEta_ppMC_pthat3 = ppMCData.Get("hjet_AvgEta")
AvgEtatruth_ppMC_pthat3 = ppMCData.Get("hjet_AvgEta_truth")
AvgEta_ppMC_pthat4 = ppMCData.Get("hjet_AvgEta")
AvgEtatruth_ppMC_pthat4 = ppMCData.Get("hjet_AvgEta_truth")

leading_pT_ppMC_pthat1 = MCData_pthat1.Get("hjet_leading_pT")
leading_PTtruth_ppMC_pthat1 = MCData_pthat1.Get("hjet_leading_pT_truth")
leading_pT_ppMC_pthat2 = MCData_pthat2.Get("hjet_leading_pT")
leading_PTtruth_ppMC_pthat2 = MCData_pthat2.Get("hjet_leading_pT_truth")
leading_pT_ppMC_pthat3 = MCData_pthat3.Get("hjet_leading_pT")
leading_PTtruth_ppMC_pthat3 = MCData_pthat3.Get("hjet_leading_pT_truth")
leading_pT_ppMC_pthat4 = MCData_pthat4.Get("hjet_leading_pT")
leading_PTtruth_ppMC_pthat4 = MCData_pthat4.Get("hjet_leading_pT_truth")

leading_Eta_ppMC_pthat1 = MCData_pthat1.Get("hjet_leading_Eta")
leading_Etatruth_ppMC_pthat1 = MCData_pthat1.Get("hjet_leading_Eta_truth")
leading_Eta_ppMC_pthat2 = MCData_pthat2.Get("hjet_leading_Eta")
leading_Etatruth_ppMC_pthat2 = MCData_pthat2.Get("hjet_leading_Eta_truth")
leading_Eta_ppMC_pthat3 = MCData_pthat3.Get("hjet_leading_Eta")
leading_Etatruth_ppMC_pthat3 = MCData_pthat3.Get("hjet_leading_Eta_truth")
leading_Eta_ppMC_pthat4 = MCData_pthat4.Get("hjet_leading_Eta")
leading_Etatruth_ppMC_pthat4 = MCData_pthat4.Get("hjet_leading_Eta_truth")

leading_Phi_ppMC_pthat1 = MCData_pthat1.Get("hjet_leading_Phi")
leading_Phitruth_ppMC_pthat1 = MCData_pthat1.Get("hjet_leadingPhi_truth")
leading_Phi_ppMC_pthat2 = MCData_pthat2.Get("hjet_leading_Phi")
leading_Phitruth_ppMC_pthat2 = MCData_pthat2.Get("hjet_leadingPhi_truth")
leading_Phi_ppMC_pthat3 = MCData_pthat3.Get("hjet_leading_Phi")
leading_Phitruth_ppMC_pthat3 = MCData_pthat3.Get("hjet_leadingPhi_truth")
leading_Phi_ppMC_pthat4 = MCData_pthat4.Get("hjet_leading_Phi")
leading_Phitruth_ppMC_pthat4 = MCData_pthat4.Get("hjet_leadingPhi_truth")

# %% [markdown]
# # 17g6a3 histogram scaling and addition

# %%
# Scaling
Xj_MC_pthat1.Scale(3232)
Xjtruth_MC_pthat1.Scale(131427)
Xj_MC_pthat2.Scale(4180)
Xjtruth_MC_pthat2.Scale(120803)
Xj_MC_pthat3.Scale(16754)
Xjtruth_MC_pthat3.Scale(273792)
Xj_MC_pthat4.Scale(25883)
Xjtruth_MC_pthat4.Scale(223442)

dPhi_MC_pthat1.Scale(3232)
dPhitruth_MC_pthat1.Scale(131427)
dPhi_MC_pthat2.Scale(4180)
dPhitruth_MC_pthat2.Scale(120803)
dPhi_MC_pthat3.Scale(16754)
dPhitruth_MC_pthat3.Scale(273792)
dPhi_MC_pthat4.Scale(25883)
dPhitruth_MC_pthat4.Scale(223442)

ptD_MC_pthat1.Scale(3232)
ptD_MC_pthat2.Scale(4180)
ptD_MC_pthat3.Scale(16754)
ptD_MC_pthat4.Scale(25883)

Multiplicity_MC_pthat1.Scale(3232)
Multiplicity_MC_pthat2.Scale(4180)
Multiplicity_MC_pthat3.Scale(16754)
Multiplicity_MC_pthat4.Scale(25883)

dEta_MC_pthat1.Scale(3232)
dEtatruth_MC_pthat1.Scale(131427)
dEta_MC_pthat2.Scale(4180)
dEtatruth_MC_pthat2.Scale(120803)
dEta_MC_pthat3.Scale(16754)
dEtatruth_MC_pthat3.Scale(273792)
dEta_MC_pthat4.Scale(25883)
dEtatruth_MC_pthat4.Scale(223442)

AvgEta_MC_pthat1.Scale(3232)
AvgEtatruth_MC_pthat1.Scale(131427)
AvgEta_MC_pthat2.Scale(4180)
AvgEtatruth_MC_pthat2.Scale(120803)
AvgEta_MC_pthat3.Scale(16754)
AvgEtatruth_MC_pthat3.Scale(273792)
AvgEta_MC_pthat4.Scale(25883)
AvgEtatruth_MC_pthat4.Scale(223442)

leading_pT_MC_pthat1.Scale(50459)
leading_PTtruth_MC_pthat1.Scale(509759)
leading_pT_MC_pthat2.Scale(54885)
leading_PTtruth_MC_pthat2.Scale(371851)
leading_pT_MC_pthat3.Scale(182247)
leading_PTtruth_MC_pthat3.Scale(503915)
leading_pT_MC_pthat4.Scale(161526)
leading_PTtruth_MC_pthat4.Scale(693695)

leading_Eta_MC_pthat1.Scale(50459)
leading_Etatruth_MC_pthat1.Scale(509759)
leading_Eta_MC_pthat2.Scale(54885)
leading_Etatruth_MC_pthat2.Scale(371851)
leading_Eta_MC_pthat3.Scale(182247)
leading_Etatruth_MC_pthat3.Scale(503915)
leading_Eta_MC_pthat4.Scale(161526)
leading_Etatruth_MC_pthat4.Scale(693695)

leading_Phi_MC_pthat1.Scale(50459)
leading_Phitruth_MC_pthat1.Scale(509759)
leading_Phi_MC_pthat2.Scale(54885)
leading_Phitruth_MC_pthat2.Scale(371851)
leading_Phi_MC_pthat3.Scale(182247)
leading_Phitruth_MC_pthat3.Scale(503915)
leading_Phi_MC_pthat4.Scale(161526)
leading_Phitruth_MC_pthat4.Scale(693695)

# Histogram-adding function
# Precondition: added_to and added_from are 1-D histograms that have the same dimensions
def Addto1D(added_to, added_from):
    x_bin_min = added_to.GetXaxis().FindBin(added_to.GetXaxis().GetXmin())
    x_bin_max = added_to.GetXaxis().FindBin(added_to.GetXaxis().GetXmax())
    i = x_bin_min
    while(i <= x_bin_max):
        added_to.SetBinContent(i, added_to.GetBinContent(i)+added_from.GetBinContent(i))
        
        # Error propogation
        added_to.SetBinError(i, TMath.Sqrt((added_to.GetBinError(i)*added_to.GetBinError(i)) + (added_from.GetBinError(i)*added_from.GetBinError(i))))
        
        i += 1
        
    return

# Add all the MC histograms into one for each variable
Xj_MC = Xj_MC_pthat1.Clone()
Addto1D(Xj_MC, Xj_MC_pthat2)
Addto1D(Xj_MC, Xj_MC_pthat3)
Addto1D(Xj_MC, Xj_MC_pthat4)
Xjtruth_MC = Xjtruth_MC_pthat1.Clone()
Addto1D(Xjtruth_MC, Xjtruth_MC_pthat2)
Addto1D(Xjtruth_MC, Xjtruth_MC_pthat3)
Addto1D(Xjtruth_MC, Xjtruth_MC_pthat4)

dPhi_MC = dPhi_MC_pthat1.Clone()
Addto1D(dPhi_MC, dPhi_MC_pthat2)
Addto1D(dPhi_MC, dPhi_MC_pthat3)
Addto1D(dPhi_MC, dPhi_MC_pthat4)
dPhitruth_MC = dPhitruth_MC_pthat1.Clone()
Addto1D(dPhitruth_MC, dPhitruth_MC_pthat2)
Addto1D(dPhitruth_MC, dPhitruth_MC_pthat3)
Addto1D(dPhitruth_MC, dPhitruth_MC_pthat4)

ptD_MC = ptD_MC_pthat1.Clone()
Addto1D(ptD_MC, ptD_MC_pthat2)
Addto1D(ptD_MC, ptD_MC_pthat3)
Addto1D(ptD_MC, ptD_MC_pthat4)

Multiplicity_MC = Multiplicity_MC_pthat1.Clone()
Addto1D(Multiplicity_MC, Multiplicity_MC_pthat2)
Addto1D(Multiplicity_MC, Multiplicity_MC_pthat3)
Addto1D(Multiplicity_MC, Multiplicity_MC_pthat4)

dEta_MC = dEta_MC_pthat1.Clone()
Addto1D(dEta_MC, dEta_MC_pthat2)
Addto1D(dEta_MC, dEta_MC_pthat3)
Addto1D(dEta_MC, dEta_MC_pthat4)
dEtatruth_MC = dEtatruth_MC_pthat1.Clone()
Addto1D(dEtatruth_MC, dEtatruth_MC_pthat2)
Addto1D(dEtatruth_MC, dEtatruth_MC_pthat3)
Addto1D(dEtatruth_MC, dEtatruth_MC_pthat4)

AvgEta_MC = AvgEta_MC_pthat1.Clone()
Addto1D(AvgEta_MC, AvgEta_MC_pthat2)
Addto1D(AvgEta_MC, AvgEta_MC_pthat3)
Addto1D(AvgEta_MC, AvgEta_MC_pthat4)
AvgEtatruth_MC = AvgEtatruth_MC_pthat1.Clone()
Addto1D(AvgEtatruth_MC, AvgEtatruth_MC_pthat2)
Addto1D(AvgEtatruth_MC, AvgEtatruth_MC_pthat3)
Addto1D(AvgEtatruth_MC, AvgEtatruth_MC_pthat4)

leading_pT_MC = leading_pT_MC_pthat1.Clone()
Addto1D(leading_pT_MC, leading_pT_MC_pthat2)
Addto1D(leading_pT_MC, leading_pT_MC_pthat3)
Addto1D(leading_pT_MC, leading_pT_MC_pthat4)
leading_PTtruth_MC = leading_PTtruth_MC_pthat1.Clone()
Addto1D(leading_PTtruth_MC, leading_PTtruth_MC_pthat2)
Addto1D(leading_PTtruth_MC, leading_PTtruth_MC_pthat3)
Addto1D(leading_PTtruth_MC, leading_PTtruth_MC_pthat4)

leading_Eta_MC = leading_Eta_MC_pthat1.Clone()
Addto1D(leading_Eta_MC, leading_Eta_MC_pthat2)
Addto1D(leading_Eta_MC, leading_Eta_MC_pthat3)
Addto1D(leading_Eta_MC, leading_Eta_MC_pthat4)
leading_Etatruth_MC = leading_Etatruth_MC_pthat1.Clone()
Addto1D(leading_Etatruth_MC, leading_Etatruth_MC_pthat2)
Addto1D(leading_Etatruth_MC, leading_Etatruth_MC_pthat3)
Addto1D(leading_Etatruth_MC, leading_Etatruth_MC_pthat4)

leading_Phi_MC = leading_Phi_MC_pthat1.Clone()
Addto1D(leading_Phi_MC, leading_Phi_MC_pthat2)
Addto1D(leading_Phi_MC, leading_Phi_MC_pthat3)
Addto1D(leading_Phi_MC, leading_Phi_MC_pthat4)
leading_Phitruth_MC = leading_Phitruth_MC_pthat1.Clone()
Addto1D(leading_Phitruth_MC, leading_Phitruth_MC_pthat2)
Addto1D(leading_Phitruth_MC, leading_Phitruth_MC_pthat3)
Addto1D(leading_Phitruth_MC, leading_Phitruth_MC_pthat4)

# Now, scale the sum histograms by the weightsums
Xj_MC.Scale(1/(0.000003))
Xjtruth_MC.Scale(1/(0.000048))

dPhi_MC.Scale(1/(0.000003))
dPhitruth_MC.Scale(1/(0.000048))

ptD_MC.Scale(1/(0.000003))

Multiplicity_MC.Scale(1/(0.000003))

dEta_MC.Scale(1/(0.000003))
dEtatruth_MC.Scale(1/(0.000048))

AvgEta_MC.Scale(1/(0.000003))
AvgEtatruth_MC.Scale(1/(0.000048))

leading_pT_MC.Scale(1/(0.000026))
leading_PTtruth_MC.Scale(1/(0.000137))

leading_Eta_MC.Scale(1/(0.000026))
leading_Etatruth_MC.Scale(1/(0.000137))

leading_Phi_MC.Scale(1/(0.000026))
leading_Phitruth_MC.Scale(1/(0.000137))

# %% [markdown]
# # 16c3b histogram scaling and addition

# %%
# Scaling
Xj_ppMC_pthat1.Scale(143404)
Xjtruth_ppMC_pthat1.Scale(1712067)
Xj_ppMC_pthat2.Scale(281656)
Xjtruth_ppMC_pthat2.Scale(1790449)
Xj_ppMC_pthat3.Scale(498146)
Xjtruth_ppMC_pthat3.Scale(1488149)
Xj_ppMC_pthat4.Scale(610971)
Xjtruth_ppMC_pthat4.Scale(1367611)

dPhi_ppMC_pthat1.Scale(143404)
dPhitruth_ppMC_pthat1.Scale(1712067)
dPhi_ppMC_pthat2.Scale(281656)
dPhitruth_ppMC_pthat2.Scale(1790449)
dPhi_ppMC_pthat3.Scale(498146)
dPhitruth_ppMC_pthat3.Scale(1488149)
dPhi_ppMC_pthat4.Scale(610971)
dPhitruth_ppMC_pthat4.Scale(1367611)

ptD_ppMC_pthat1.Scale(143404)
ptD_ppMC_pthat2.Scale(281656)
ptD_ppMC_pthat3.Scale(498146)
ptD_ppMC_pthat4.Scale(610971)

Multiplicity_ppMC_pthat1.Scale(143404)
Multiplicity_ppMC_pthat2.Scale(281656)
Multiplicity_ppMC_pthat3.Scale(498146)
Multiplicity_ppMC_pthat4.Scale(610971)

dEta_ppMC_pthat1.Scale(143404)
dEtatruth_ppMC_pthat1.Scale(1712067)
dEta_ppMC_pthat2.Scale(281656)
dEtatruth_ppMC_pthat2.Scale(1790449)
dEta_ppMC_pthat3.Scale(498146)
dEtatruth_ppMC_pthat3.Scale(1488149)
dEta_ppMC_pthat4.Scale(610971)
dEtatruth_ppMC_pthat4.Scale(1367611)

AvgEta_ppMC_pthat1.Scale(143404)
AvgEtatruth_ppMC_pthat1.Scale(1712067)
AvgEta_ppMC_pthat2.Scale(281656)
AvgEtatruth_ppMC_pthat2.Scale(1790449)
AvgEta_ppMC_pthat3.Scale(498146)
AvgEtatruth_ppMC_pthat3.Scale(1488149)
AvgEta_ppMC_pthat4.Scale(610971)
AvgEtatruth_ppMC_pthat4.Scale(1367611)

leading_pT_ppMC_pthat1.Scale(1133911)
leading_PTtruth_ppMC_pthat1.Scale(3450210)
leading_pT_ppMC_pthat2.Scale(1565971)
leading_PTtruth_ppMC_pthat2.Scale(3289148)
leading_pT_ppMC_pthat3.Scale(1994410)
leading_PTtruth_ppMC_pthat3.Scale(2667643)
leading_pT_ppMC_pthat4.Scale(2144932)
leading_PTtruth_ppMC_pthat4.Scale(2506674)

leading_Eta_ppMC_pthat1.Scale(1133911)
leading_Etatruth_ppMC_pthat1.Scale(3450210)
leading_Eta_ppMC_pthat2.Scale(1565971)
leading_Etatruth_ppMC_pthat2.Scale(3289148)
leading_Eta_ppMC_pthat3.Scale(1994410)
leading_Etatruth_ppMC_pthat3.Scale(2667643)
leading_Eta_ppMC_pthat4.Scale(2144932)
leading_Etatruth_ppMC_pthat4.Scale(2506674)

leading_Phi_ppMC_pthat1.Scale(1133911)
leading_Phitruth_ppMC_pthat1.Scale(3450210)
leading_Phi_ppMC_pthat2.Scale(1565971)
leading_Phitruth_ppMC_pthat2.Scale(3289148)
leading_Phi_ppMC_pthat3.Scale(1994410)
leading_Phitruth_ppMC_pthat3.Scale(2667643)
leading_Phi_ppMC_pthat4.Scale(2144932)
leading_Phitruth_ppMC_pthat4.Scale(2506674)


# Add all the MC histograms into one for each variable
Xj_ppMC = Xj_ppMC_pthat1.Clone()
Addto1D(Xj_ppMC, Xj_ppMC_pthat2)
Addto1D(Xj_ppMC, Xj_ppMC_pthat3)
Addto1D(Xj_ppMC, Xj_ppMC_pthat4)
Xjtruth_ppMC = Xjtruth_ppMC_pthat1.Clone()
Addto1D(Xjtruth_ppMC, Xjtruth_ppMC_pthat2)
Addto1D(Xjtruth_ppMC, Xjtruth_ppMC_pthat3)
Addto1D(Xjtruth_ppMC, Xjtruth_ppMC_pthat4)

dPhi_ppMC = dPhi_ppMC_pthat1.Clone()
Addto1D(dPhi_ppMC, dPhi_ppMC_pthat2)
Addto1D(dPhi_ppMC, dPhi_ppMC_pthat3)
Addto1D(dPhi_ppMC, dPhi_ppMC_pthat4)
dPhitruth_ppMC = dPhitruth_ppMC_pthat1.Clone()
Addto1D(dPhitruth_ppMC, dPhitruth_ppMC_pthat2)
Addto1D(dPhitruth_ppMC, dPhitruth_ppMC_pthat3)
Addto1D(dPhitruth_ppMC, dPhitruth_ppMC_pthat4)

ptD_ppMC = ptD_ppMC_pthat1.Clone()
Addto1D(ptD_ppMC, ptD_ppMC_pthat2)
Addto1D(ptD_ppMC, ptD_ppMC_pthat3)
Addto1D(ptD_ppMC, ptD_ppMC_pthat4)

Multiplicity_ppMC = Multiplicity_ppMC_pthat1.Clone()
Addto1D(Multiplicity_ppMC, Multiplicity_ppMC_pthat2)
Addto1D(Multiplicity_ppMC, Multiplicity_ppMC_pthat3)
Addto1D(Multiplicity_ppMC, Multiplicity_ppMC_pthat4)

dEta_ppMC = dEta_ppMC_pthat1.Clone()
Addto1D(dEta_ppMC, dEta_ppMC_pthat2)
Addto1D(dEta_ppMC, dEta_ppMC_pthat3)
Addto1D(dEta_ppMC, dEta_ppMC_pthat4)
dEtatruth_ppMC = dEtatruth_ppMC_pthat1.Clone()
Addto1D(dEtatruth_ppMC, dEtatruth_ppMC_pthat2)
Addto1D(dEtatruth_ppMC, dEtatruth_ppMC_pthat3)
Addto1D(dEtatruth_ppMC, dEtatruth_ppMC_pthat4)

AvgEta_ppMC = AvgEta_ppMC_pthat1.Clone()
Addto1D(AvgEta_ppMC, AvgEta_ppMC_pthat2)
Addto1D(AvgEta_ppMC, AvgEta_ppMC_pthat3)
Addto1D(AvgEta_ppMC, AvgEta_ppMC_pthat4)
AvgEtatruth_ppMC = AvgEtatruth_ppMC_pthat1.Clone()
Addto1D(AvgEtatruth_ppMC, AvgEtatruth_ppMC_pthat2)
Addto1D(AvgEtatruth_ppMC, AvgEtatruth_ppMC_pthat3)
Addto1D(AvgEtatruth_ppMC, AvgEtatruth_ppMC_pthat4)

leading_pT_ppMC = leading_pT_MC_pthat1.Clone()
Addto1D(leading_pT_ppMC, leading_pT_ppMC_pthat2)
Addto1D(leading_pT_ppMC, leading_pT_ppMC_pthat3)
Addto1D(leading_pT_ppMC, leading_pT_ppMC_pthat4)
leading_PTtruth_ppMC = leading_PTtruth_ppMC_pthat1.Clone()
Addto1D(leading_PTtruth_ppMC, leading_PTtruth_ppMC_pthat2)
Addto1D(leading_PTtruth_ppMC, leading_PTtruth_ppMC_pthat3)
Addto1D(leading_PTtruth_ppMC, leading_PTtruth_ppMC_pthat4)

leading_Eta_ppMC = leading_Eta_MC_pthat1.Clone()
Addto1D(leading_Eta_ppMC, leading_Eta_ppMC_pthat2)
Addto1D(leading_Eta_ppMC, leading_Eta_ppMC_pthat3)
Addto1D(leading_Eta_ppMC, leading_Eta_ppMC_pthat4)
leading_Etatruth_ppMC = leading_Etatruth_ppMC_pthat1.Clone()
Addto1D(leading_Etatruth_ppMC, leading_Etatruth_ppMC_pthat2)
Addto1D(leading_Etatruth_ppMC, leading_Etatruth_ppMC_pthat3)
Addto1D(leading_Etatruth_ppMC, leading_Etatruth_ppMC_pthat4)

leading_Phi_ppMC = leading_Phi_ppMC_pthat1.Clone()
Addto1D(leading_Phi_ppMC, leading_Phi_ppMC_pthat2)
Addto1D(leading_Phi_ppMC, leading_Phi_ppMC_pthat3)
Addto1D(leading_Phi_ppMC, leading_Phi_ppMC_pthat4)
leading_Phitruth_ppMC = leading_Phitruth_ppMC_pthat1.Clone()
Addto1D(leading_Phitruth_ppMC, leading_Phitruth_ppMC_pthat2)
Addto1D(leading_Phitruth_ppMC, leading_Phitruth_ppMC_pthat3)
Addto1D(leading_Phitruth_ppMC, leading_Phitruth_ppMC_pthat4)

# Now, scale the sum histograms by the weightsums
Xj_ppMC.Scale(1/(3580.737))
Xjtruth_ppMC.Scale(1/(21780.2))

dPhi_ppMC.Scale(1/(3580.737))
dPhitruth_ppMC.Scale(1/(21780.2))

ptD_ppMC.Scale(1/(3580.737))

Multiplicity_ppMC.Scale(1/(3580.737))

dEta_ppMC.Scale(1/(3580.737))
dEtatruth_ppMC.Scale(1/(21780.2))

AvgEta_ppMC.Scale(1/(3580.737))
AvgEtatruth_ppMC.Scale(1/(21780.2))

leading_pT_ppMC.Scale(1/(19165.36))
leading_PTtruth_ppMC.Scale(1/(41725.45))

leading_Eta_ppMC.Scale(1/(19165.36))
leading_Etatruth_ppMC.Scale(1/(41725.45))

leading_Phi_ppMC.Scale(1/(19165.36))
leading_Phitruth_ppMC.Scale(1/(41725.45))

# %%
# Graph Xj
Xj_ppMC.SetTitle("Xj distribution; Xj; 1/N dN/dXj")
Xj_ppMC.SetMaximum(0.01)
Xj_ppMC.GetYaxis().SetTitleOffset(1)
Xj_ppMC.GetYaxis().SetLabelSize(0.02)
Xj_ppMC.GetYaxis().SetTitleSize(0.04)
Xj_ppMC.SetLineColor(1)
Xj_ppMC.SetMarkerColor(1)
Xj_ppMC.SetMarkerStyle(20)
Xj_MC.SetLineColor(2)
Xj_MC.SetMarkerColor(2)
Xj_MC.SetMarkerStyle(20)
Xjtruth_MC.SetLineColor(3)
Xjtruth_MC.SetMarkerColor(3)
Xjtruth_MC.SetMarkerStyle(20)
Xjtruth_ppMC.SetLineColor(4)
Xjtruth_ppMC.SetMarkerColor(4)
Xjtruth_ppMC.SetMarkerStyle(20)

c = TCanvas("c", "c", 1000, 1000)
Xj_ppMC.Draw()
Xj_MC.Draw("same")
Xjtruth_MC.Draw("HIST same")
Xjtruth_ppMC.Draw("HIST same")
c.Draw()

legend = TLegend(0.78, 0.77, 0.98, .94)
legend.AddEntry(Xj_MC, "pPb MC results", "l")
legend.AddEntry(Xjtruth_MC, "pPb MC truth", "l")
legend.AddEntry(Xj_ppMC, "pp MC results", "l")
legend.AddEntry(Xjtruth_ppMC, "pp MC truth", "l")
legend.Draw()
c.SaveAs("Xj_MCcomparison.png")
# Out:
# Error in <TMacOSXSystem::WorkingDirectory>: getcwd() failed
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file Xj_MCcomparison.png has been created
